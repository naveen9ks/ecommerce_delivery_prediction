# %% [markdown]
# # E COMMERCE PRODUCT DELIVERY PREDICTION

# %% [markdown]
# IMPORTING LIBRARIES

# %%
import pandas as pd     # to read data set
import numpy as np      # to do mathematical operations
import matplotlib.pyplot as plt     # to do visualizations like bar chart, etc..,
import seaborn as sns       # to do analytical visualizations like pie chart, etc..,

# %% [markdown]
# # DATA PREPROCESSING

# %%
df= pd.read_csv("E_Commerce.csv")       # to  load dataset
df.head()        # show top 4 rows of a dataset
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1

# %%
df.describe()        # shows description about data columns
# Out:
#                 ID  Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count  10999.00000         10999.000000     10999.000000         10999.000000
# mean    5500.00000             4.054459         2.990545           210.196836
# std     3175.28214             1.141490         1.413603            48.063272
# min        1.00000             2.000000         1.000000            96.000000
# 25%     2750.50000             3.000000         2.000000           169.000000
# 50%     5500.00000             4.000000         3.000000           214.000000
# 75%     8249.50000             5.000000         4.000000           251.000000
# max    10999.00000             7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# count     10999.000000      10999.000000   10999.000000         10999.000000
# mean          3.567597         13.373216    3634.016729             0.596691
# std           1.522860         16.205527    1635.377251             0.490584
# min           2.000000          1.000000    1001.000000             0.000000
# 25%           3.000000          4.000000    1839.500000             0.000000
# 50%           3.000000          7.000000    4149.000000             1.000000
# 75%           4.000000         10.000000    5050.000000             1.000000
# max          10.000000         65.000000    7846.000000             1.000000

# %%
df.info()        # know information about data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
# remove unwanted warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # STEP 1: EXPLORATORY DATA ANALYSIS(EDA)

# %%
df.columns      # shows details of columns
# Out:
# Index(['ID', 'Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls',
#        'Customer_rating', 'Cost_of_the_Product', 'Prior_purchases',
#        'Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms',
#        'Reached.on.Time_Y.N'],
#       dtype='object')

# %% [markdown]
# # STEP1(1) UNIVARIATE ANALYSIS

# %% [markdown]
# (CATEGORICAL DATA)

# %% [markdown]
# 1.1 WAREHOUSE BLOCK ANALYSIS

# %%
ware= df["Warehouse_block"].value_counts()      # calculates total value counts

# %%
plt.pie(ware, labels=ware.values)       # creates pie chart
plt.legend(ware.index)      # shows color identification
plt.title("Warehouse Block Analysis")       # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# 1.2 SHIPMENT ANALYSIS

# %%
sns.countplot(x="Mode_of_Shipment", data=df, color='r',width=0.25)      # creates bar chart
plt.xlabel("Mode of Shipment")      # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Shipment Analysis")      # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# 1.3 CUSTOMER RATING ANALYSIS

# %%
sns.countplot(x="Customer_rating", data=df, color='r', width=0.5)       # creates bar chart
plt.xlabel("Customer Rating")       # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Customer Rating Analysis")       # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# 1.4 PRODUCT IMPORTANCE ANALYSIS

# %%
sns.countplot(x="Product_importance", data=df, color='r', width=0.25)       # creates bar chart
plt.xlabel("Product Importance")        # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Product Importance Analysis")        # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# 1.5 GENDER ANALYSIS

# %%
sns.countplot(x="Gender", data=df, color='r', width=0.25)       # creates bar chart
plt.xlabel("Gender")        # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Gender Analysis")        # shows title on chart
plt.show()      # shows entire chart

# %% [markdown]
# 1.6 REACHED ON TIME ANALYSIS

# %%
sns.countplot(x="Reached.on.Time_Y.N", data=df, color='r', width=0.25)      # creates bar chart
plt.xlabel("Reached ON Time Y/N")       # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Reached ON Time Y/N")        # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# (NUMERICAL DATA)

# %% [markdown]
# 1.7 CUSTOMER CARE ANALYSIS

# %%
plt.hist("Customer_care_calls", color='r', data=df)     # creates histogram chart
plt.xlabel("Customer Care Calls")       # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Customer Care Analysis")     # shows title on chart
plt.show()      # shows entire chart

# %% [markdown]
# 1.8 COST OF PRODUCT ANALYSIS

# %%
plt.hist("Cost_of_the_Product", data=df, color='r')     # creates histogram chart
plt.xlabel("Cost of Product")       # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Cost of Product Analysis")       # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# 1.9 DISCOUNT ANALYSIS

# %%
plt.hist("Discount_offered", data=df, color='r')        # creates histogram chart
plt.xlabel("Discount Offered")      # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Discount Analysis")      # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# 1.10 WEIGHT ANALYSIS

# %%
plt.hist("Weight_in_gms", data=df, color='r')       # creates histogram chart
plt.xlabel("Weight in gms")     # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Weight Analysis")        # shows title of chart
plt.show()      # shows entiere chart

# %% [markdown]
# 1.11 PRIOR PURCHASE ANALYSIS

# %%
plt.hist("Prior_purchases", data=df, color='r')     # creates histogram chart
plt.xlabel("Prior Purchases")       # shows title on x-axis
plt.ylabel("Frequency")     # shows title on y-axis
plt.title("Prior Purchase Analysis")        # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# # STEP 1(2) BIVARIATE ANALYSIS

# %% [markdown]
# Warehouse Block Delivery Analysis

# %%
sns.countplot(x="Warehouse_block", hue="Reached.on.Time_Y.N", data=df, palette='dark:r', width=0.5)     # creates bar chart
plt.xlabel("Warehouse Block")       # shows title on x-axis
plt.ylabel("Count")     # shows title on y-axis
plt.title("Warehouse Block Delivery Analysis")      # shows title of chart
plt.show()      # displays entire chart

# %% [markdown]
# Shipment Delivery Analysis

# %%
sns.countplot(x="Mode_of_Shipment", hue="Reached.on.Time_Y.N", palette='dark:r', data=df, width=0.3)        # creates bar chart
plt.xlabel("Mode of Shipment")      # shows title on x-axis
plt.ylabel("Count")     # shows title on y-axis
plt.title("Shipment Delivery Analysis")     # shows title of chart
plt.show()      # displays entire chart

# %% [markdown]
# Customer Care Delivery Analysis

# %%
sns.countplot(x="Customer_care_calls", hue="Reached.on.Time_Y.N", data=df, palette='dark:r', width=0.5)     # create bar chart
plt.xlabel("Customer care calls")       # shows title on x-axis
plt.ylabel("Count")     # shows title on y-axis
plt.title("Customer Care Delivery Analysis")        # shows title for chart
plt.show()      # shows entire chart

# %% [markdown]
# Customer Rating Delivery Analysis

# %%
sns.countplot(x="Customer_rating", hue="Reached.on.Time_Y.N", palette='dark:r', data=df, width=0.5)     # creates bar chart
plt.xlabel("Customer Rating")       # shows title on x-axis
plt.ylabel("Count")     # shows title on y-axis
plt.title("Customer Rating Delivery Analysis")      # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# Prior Purchases Delivery Analysis

# %%
sns.countplot(x="Prior_purchases", hue="Reached.on.Time_Y.N", palette='dark:r', data=df, width=0.5)     # creates bar chart
plt.xlabel("Prior Purchases")       # shows title on x-axis
plt.ylabel("Count")     # shows title on y-axis
plt.title("Prior Purchases Delivery Analysis")      # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# Product Importance Delivery Analysis

# %%
sns.countplot(x="Product_importance", hue="Reached.on.Time_Y.N", palette='dark:r', data=df, width=0.5)      # creates bar chart
plt.xlabel("Product Importance")        # shows title on x-axis
plt.ylabel("Count")     # shows title on y-axis
plt.title("Product Importance Delivery Analysis")       # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# Gender Based Delivery Analysis

# %%
sns.countplot(x="Gender", hue="Reached.on.Time_Y.N", palette='dark:r', data=df, width=0.3)      # creates bar chart
plt.xlabel("Gender")        # shows title on x-axis
plt.ylabel("Count")     # shows title on y-axis
plt.title("Gender Delivery Analysis")       # shows title of chart
plt.show()      # shows entire chart

# %% [markdown]
# # STEP1(3): MULTIVARIATE ANALYSIS

# %% [markdown]
# Cost of Product vs Discount Offered over Reached ON Time Analysis

# %%
sns.scatterplot(x="Cost_of_the_Product", y="Discount_offered", hue="Reached.on.Time_Y.N", data=df, palette='dark:r')        # creates scatter plot
plt.xlabel("Cost")      # shows title on x-axis
plt.ylabel("Discount")      # shows title on y-axis
plt.title("Cost of Product vs Discount Offered Analysis")       # shows title of chart
plt.legend()        # displays color identification
plt.show()      # shows entire chart

# %% [markdown]
# Cost of Product vs Weight in gms over Reached ON Time Analysis

# %%
sns.scatterplot(x="Cost_of_the_Product", y="Weight_in_gms", hue="Reached.on.Time_Y.N", data=df, palette='dark:r')       # creates scatter plot
plt.xlabel("Cost")      # shows title on x-axis
plt.ylabel("Weight")        # shows title on y-axis
plt.title("Cost of Product vs Weight of Product Analysis")      # shows title of chart
plt.legend()        # creates color identification
plt.show()      # displays entire chart

# %% [markdown]
# # STEP 2:CORRELATION MATRIX

# %%
corr_matrix= df.corr(numeric_only=True)     # creates correlation matrix

# %%
plt.figure(figsize=(10,8))      # creates chart with given size
sns.heatmap(corr_matrix, annot= True, cmap='coolwarm', fmt=".2f", linewidths=0.5)       # creates coorelation chart with values
# Out:
# <Axes: >

# %% [markdown]
# # STEP3: DETECTING OUTLIERS

# %% [markdown]
# Cost of Product Outliers

# %%
df.boxplot("Cost_of_the_Product")       # creates box plot
plt.show()           # shows box plot chart

# %% [markdown]
# Product Weight Outliers

# %%
df.boxplot("Weight_in_gms")     # creates box plot
plt.show()      # shows entire box plot

# %% [markdown]
# Product Discount Outliers

# %%
df.boxplot("Discount_offered")      # creates box plot
plt.show()      # displays entire chart

# %% [markdown]
# # STEP 4: REMOVE OUTLIERS

# %%
# remove outliers by Inter Quantile Range (IQR) method
Q1= df['Discount_offered'].quantile(0.25)
Q3= df['Discount_offered'].quantile(0.75)
IQR= Q3- Q1


lower= Q1-0.5*IQR
upper= Q3-0.5*IQR

# %%
df_cleaned= df[(df['Discount_offered']>=lower) & (df['Discount_offered']<=upper)]       # creates cleaned data

# %% [markdown]
# Visualize Cleaned Data

# %%
plt.boxplot(df_cleaned['Discount_offered'])     # creates box plot
plt.grid()      # shows grid lines
plt.show()      # shows entire chart

# %% [markdown]
# # STEP 5: BUILD MODEL

# %% [markdown]
#     Inference:
#         From the given data set, the data's were observed as Classification problem
#         So we are moving with Supervised Learning Models

# %%
df["Reached.on.Time_Y.N"].value_counts()        # calculates total values of each category
# Out:
# Reached.on.Time_Y.N
# 1    6563
# 0    4436
# Name: count, dtype: int64

# %% [markdown]
# the target is in the ratio of 60:40, so the data is maximum balanced

# %% [markdown]
# IMPORT LIBRARIES

# %%
from sklearn.model_selection import train_test_split        # importing train test split
from sklearn.preprocessing import StandardScaler, LabelEncoder        # importing preprocessing libraries
from sklearn.linear_model import LogisticRegression     # importing Logistic Regression library
from sklearn.tree import DecisionTreeClassifier     # importing tree model
from sklearn.ensemble import RandomForestClassifier     # importing ensemble technique
from xgboost import XGBClassifier       # importing xgbclassifier model
from sklearn.neighbors import KNeighborsClassifier      # importing neighbours model
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, classification_report        # importing evaluation techniques

# %%
df=df.drop("ID", axis=1)

# %% [markdown]
# Label Encoding

# %%
# converting categorical column to encoding
le= LabelEncoder()

for col in ['Warehouse_block', 'Mode_of_Shipment','Product_importance', 'Gender']:

    df[col]= le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Warehouse_block  Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0                3                 0                    4                2
# 1                4                 0                    4                5
# 2                0                 0                    2                2
# 3                1                 0                    3                3
# 4                2                 0                    2                2
#
#    Cost_of_the_Product  Prior_purchases  Product_importance  Gender  \
# 0                  177                3                   1       0
# 1                  216                2                   1       1
# 2                  183                4                   1       1
# 3                  176                4                   2       1
# 4                  184                3                   2       0
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1

# %% [markdown]
# Defining features and target

# %%
# x is a input feature
X= df[['Warehouse_block', 'Mode_of_Shipment', 'Customer_care_calls','Customer_rating', 'Cost_of_the_Product', 'Prior_purchases','Product_importance', 'Gender', 'Discount_offered', 'Weight_in_gms']]
y= df['Reached.on.Time_Y.N']        # target feature

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Warehouse_block      10999 non-null  int64
#  1   Mode_of_Shipment     10999 non-null  int64
#  2   Customer_care_calls  10999 non-null  int64
#  3   Customer_rating      10999 non-null  int64
#  4   Cost_of_the_Product  10999 non-null  int64
#  5   Prior_purchases      10999 non-null  int64
#  6   Product_importance   10999 non-null  int64
#  7   Gender               10999 non-null  int64
#  8   Discount_offered     10999 non-null  int64
#  9   Weight_in_gms        10999 non-null  int64
#  10  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(11)
# memory usage: 945.4 KB

# %% [markdown]
# Apply onehot encoding

# %% [markdown]
# Split train test data

# %%
X_train, X_test, y_train, y_test= train_test_split(X, y,test_size=0.3, random_state=42)     # train test split in 70:30 ratio

# %% [markdown]
# (1)LOGISTIC REGRESSION MODEL

# %%
model1= LogisticRegression()     # select the model
model1.fit(X_train,y_train)      # fit the model
# Out:
# LogisticRegression()

# %% [markdown]
# Prediction

# %%
y_pred= model1.predict(X_test)      # predict the model

# %% [markdown]
# Evaluation

# %%
Accuracy = accuracy_score(y_test, y_pred)       # calculates accuracy value
Precision= precision_score(y_test, y_pred)      # calculates precision value
Confusion= confusion_matrix(y_test,y_pred)      # prepares confusion matrix
classification= classification_report(y_test, y_pred)       # prepares classification report


print(f'Accuracy:{Accuracy:.2f}')       # shows accuracy score
print(f'Precision:{Precision:.2f}')     # shows precision score
print(f'Confusion Matrix:{Confusion}')      # shows confusion matrix
print(f'Classification Report:{classification}')        # shows classification report
# Out:
# Accuracy:0.63
# Precision:0.71
# Confusion Matrix:[[ 766  546]
#  [ 662 1326]]
# Classification Report:              precision    recall  f1-score   support
#
#            0       0.54      0.58      0.56      1312
#            1       0.71      0.67      0.69      1988
#
#     accuracy                           0.63      3300
#    macro avg       0.62      0.63      0.62      3300
# weighted avg       0.64      0.63      0.64      3300

# %% [markdown]
# (2)DECISION TREE

# %%
model2= DecisionTreeClassifier()        # selects the model
model2.fit(X_train, y_train)        # fit the model
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Prediction

# %%
y_pred= model2.predict(X_test)      # predicts the model

# %% [markdown]
# Evaluation

# %%
Accuracy = accuracy_score(y_test, y_pred)       # calculates accuracy score
Precision= precision_score(y_test, y_pred)      # calculates precision score
Confusion= confusion_matrix(y_test,y_pred)      # prepares confusion matrix
classification= classification_report(y_test, y_pred)       # prepares classification report


print(f'Accuracy:{Accuracy:.2f}')       # shows accuracy value
print(f'Precision:{Precision:.2f}')     # shows precision value
print(f'Confusion Matrix:{Confusion}')      # shows confusion matrix
print(f'Classification Report:{classification}')        # shows classification report
# Out:
# Accuracy:0.64
# Precision:0.70
# Confusion Matrix:[[ 728  584]
#  [ 602 1386]]
# Classification Report:              precision    recall  f1-score   support
#
#            0       0.55      0.55      0.55      1312
#            1       0.70      0.70      0.70      1988
#
#     accuracy                           0.64      3300
#    macro avg       0.63      0.63      0.63      3300
# weighted avg       0.64      0.64      0.64      3300

# %% [markdown]
# (3) RANDOM FOREST

# %%
model3= RandomForestClassifier()        # selects the model
model3.fit(X_train,y_train)     # fits the model
# Out:
# RandomForestClassifier()

# %% [markdown]
# Prediction

# %%
y_pred= model3.predict(X_test)      # predicts the model

# %% [markdown]
# Evaluation

# %%
Accuracy= accuracy_score(y_pred, y_test)        # calculates accuracy score
Precision= precision_score(y_pred, y_test)      # calculates precision score
Confusion= confusion_matrix(y_pred, y_test)     # prepares confusion matrix
classification= classification_report(y_pred, y_test)       # prepares classification report

print(f'Accuracy:{Accuracy:.2f}')       # shows accuracy value
print(f'Precision:{Precision:.2f}')     # shows precision value
print(classification)       # shows classification report
print(Confusion)        # shows confusion matrix
# Out:
# Accuracy:0.67
# Precision:0.64
#               precision    recall  f1-score   support
#
#            0       0.71      0.56      0.63      1661
#            1       0.64      0.77      0.70      1639
#
#     accuracy                           0.67      3300
#    macro avg       0.67      0.67      0.66      3300
# weighted avg       0.67      0.67      0.66      3300
#
# [[ 936  725]
#  [ 376 1263]]

# %% [markdown]
# (4) KNN MODEL

# %%
model4= KNeighborsClassifier()       # selects the model
model4.fit(X_train, y_train)     # fits the model
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Prediction

# %%
y_pred= model4.predict(X_test)       # predicts the model

# %% [markdown]
# Evaluation

# %%
Accuracy = accuracy_score(y_test, y_pred)       # calculates accuracy score
Precision= precision_score(y_test, y_pred)      # calculates precision score
Confusion= confusion_matrix(y_test,y_pred)      # prepares confusion matrix
classification= classification_report(y_test, y_pred)       # prepares classification report


print(f'Accuracy:{Accuracy:.2f}')       # shows accuracy value
print(f'Precision:{Precision:.2f}')     # shows precision value
print(f'{Confusion}')      # shows confusion matrix
print(f'{classification}')        # shows classification report
# Out:
# Accuracy:0.65
# Precision:0.73
# [[ 807  505]
#  [ 645 1343]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.58      1312
#            1       0.73      0.68      0.70      1988
#
#     accuracy                           0.65      3300
#    macro avg       0.64      0.65      0.64      3300
# weighted avg       0.66      0.65      0.65      3300

# %% [markdown]
# (5) XGBOOST

# %%
model5= XGBClassifier()      # selects the model
model5.fit(X_train, y_train)     # fits the model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %% [markdown]
# Prediction

# %%
y_pred= model5.predict(X_test)      # predicts the model

# %% [markdown]
# Evaluation

# %%
Accuracy = accuracy_score(y_test, y_pred)       # calculates accuracy score
Precision= precision_score(y_test, y_pred)      # calculates precision score
Confusion= confusion_matrix(y_test,y_pred)      # prepares confusion matrix
classification= classification_report(y_test, y_pred)       # prepares classification report


print(f'Accuracy:{Accuracy:.2f}')       # shows accuracy value
print(f'Precision:{Precision:.2f}')     # shows precision value
print(f'{Confusion}')       # shows cofusion matrix
print(f'{classification}')      # shows classification report
# Out:
# Accuracy:0.66
# Precision:0.74
# [[ 851  461]
#  [ 659 1329]]
#               precision    recall  f1-score   support
#
#            0       0.56      0.65      0.60      1312
#            1       0.74      0.67      0.70      1988
#
#     accuracy                           0.66      3300
#    macro avg       0.65      0.66      0.65      3300
# weighted avg       0.67      0.66      0.66      3300

# %% [markdown]
# # STEP 6:HYPER PARAMETER TUNING

# %% [markdown]
# Import Libraries

# %%
from sklearn.model_selection import GridSearchCV        # selects GridSearchCV for model tuning

# %% [markdown]
# Parametric Tuning

# %%
# choosing parameter grid
param_grid= {
    'n_estimators':[100, 150, 200],
    'max_depth':[5,10,None],
    'max_samples_split':[2,5,10],
    'max_samples_leaf':[1,2,4],
    'criterion':['gini', 'entropy']

}

# %% [markdown]
# GridSearch CV

# %%
# grid search operations
grid_search= GridSearchCV(
    estimator=XGBClassifier(),
    param_grid= param_grid,
    cv=5,       # cross validation
    n_jobs=1,
    verbose=1
)

# %% [markdown]
# Fit Model

# %%
grid_search.fit(X_train,y_train)        # fits the model
# Out:
# Fitting 5 folds for each of 162 candidates, totalling 810 fits
# GridSearchCV(cv=5,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, feature_weights=None,
#                                      gamma=None, grow_policy=None,
#                                      importance_type=None,
#                                      interaction_constraints=Non...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None, ...),
#              n_jobs=1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, None],
#                          'max_samples_leaf': [1, 2, 4],
#                          'max_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 150, 200]},
#              verbose=1)

# %% [markdown]
# Best Estimator

# %%
best_xg= grid_search.best_estimator_        # selects best model

# %% [markdown]
# Prediction

# %%
y_pred= best_xg.predict(X_test)     # predicts the value

# %% [markdown]
# Evaluation

# %%
Accuracy = accuracy_score(y_test, y_pred)       # calculates accuracy score
Precision= precision_score(y_test, y_pred)      # calculates precision score
Confusion= confusion_matrix(y_test,y_pred)      # prepares confusion matrix
classification= classification_report(y_test, y_pred)       # prepares classification report


print(f'Accuracy:{Accuracy:.2f}')       # shows accuracy value
print(f'Precision:{Precision:.2f}')     # shows precision value
print(f'Confusion Matrix:{Confusion}')      # shows confusion matrix
print(f'Classification Report:{classification}')        # shows classification report
# Out:
# Accuracy:0.66
# Precision:0.75
# Confusion Matrix:[[ 875  437]
#  [ 677 1311]]
# Classification Report:              precision    recall  f1-score   support
#
#            0       0.56      0.67      0.61      1312
#            1       0.75      0.66      0.70      1988
#
#     accuracy                           0.66      3300
#    macro avg       0.66      0.66      0.66      3300
# weighted avg       0.68      0.66      0.67      3300

# %% [markdown]
# # STEP 7: DEPLOYMENT

# %%
import streamlit as st      # to deploy the model
import joblib       # to save and load model

# %%
model= joblib.dump(model5,"ecom.pkl")       # save the model

# %%
model6= joblib.load("ecom.pkl")     # load the model

# %%
# title of page
st.title("E-Commerce delivery prediction")


# input features
Block= st.selectbox("Ware house block",list(range(0,5)))
Shipment= st.selectbox("shipment",list(range(0,3)))
customercalls= st.selectbox("customer calls",list(range(1,8)))
CustomerRating= st.selectbox("Customer rating",list(range(1,6)))
CostofProduct= st.number_input("Enter cost of product")
Priorpurchase=st.selectbox("Prior purchase",list(range(2,11)))
ProdctImportance= st.selectbox("Product Importance",list(range(0,3)))
Gender= st.selectbox("Gender",[0,1])
Discount= st.number_input("Enter Discount Offered")
Weight= st.number_input("Enter weight in gms")
# Out:
# 2025-09-01 18:48:32.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.827 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.829 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.830 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.831 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.844 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.845 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.846 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.848 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.849 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.857 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.861 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.862 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.863 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.864 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.865 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.866 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.874 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.877 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.878 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.879 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.880 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.883 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.884 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.885 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.886 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.888 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.889 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.890 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.891 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.892 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.893 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.894 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.895 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.896 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.897 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.898 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.899 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:32.901 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# calculates and predicts
input_data= np.array([[Block,Shipment,customercalls,CustomerRating,ProdctImportance,Gender,CostofProduct,Priorpurchase,Discount,Weight]])


if st.button("Predict"):
    prediction= model6.predict(input_data)[0]
    
    if prediction==1:
        st.success("Delivered ON time")
    else:
        st.error("Delivered Not-ON time")
# Out:
# 2025-09-01 18:48:40.637 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:40.639 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:40.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:40.640 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:40.642 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-09-01 18:48:40.643 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %% [markdown]
# # STEP 8: CONVERT VSCODE TO SCRIPT

# %%
# !jupyter nbconvert --to script e_com.ipynb      # converts vscode to script
# Out:
# [NbConvertApp] WARNING | pattern '#' matched no files
# [NbConvertApp] WARNING | pattern 'converts' matched no files
# [NbConvertApp] WARNING | pattern 'vscode' matched no files
# [NbConvertApp] WARNING | pattern 'to' matched no files
# [NbConvertApp] WARNING | pattern 'script' matched no files
# [NbConvertApp] Converting notebook e_com.ipynb to script
# [NbConvertApp] Writing 19021 bytes to e_com.py
